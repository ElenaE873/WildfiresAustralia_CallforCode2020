# %% [markdown]
# #### Objective of Analysis:
#
#
# To observe and gain insight and an understanding of wilfires per region.  Understanding the historical files year to year, as well as region to region, will aid in associating this data with weather and vegetation index.

# %% [markdown]
# - [1. Estimated Fire Radiative Power Year to Year for All Regions](#FireAreaYtY)
#
# - [2. Estimated Fire Radiative Power Year to Year - NSW Region](#FireAreaNSW)
#
# - [3. Estimated Fire Radiative Power Year to Year - QL Region](#FireAreaQL)
#
# - [4. Estimated Fire Radiative Power Year to Year - TA Region](#FireAreaTA)
#
# - [5. Estimated Fire Radiative Power Year to Year - WA Region](#FireAreaWA)
#
# > - [5.1 Estimated Fire Radiative Power Year to Year - 'NSW', 'QL', 'TA', 'WA'  Region](#FireArea1stFour)
#
# - [6. Estimated Fire Radiative Power Year to Year - SA Region](#FireAreaSA)
#
# - [7. Estimated Fire Radiative Power Year to Year - NT Region](#FireAreaNT)
#
# - [8. Estimated Fire Radiative Power Year to Year - VI Region](#FireAreaVI)
#
# > - [8.1 Estimated Fire Radiative Power Year to Year - 'SA', 'NT', and "VI' Region](#FireArea2ndset)

# %%
# Import the necessary packages for analysis and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt, mpld3
# %matplotlib inline
import json
import datetime

from shapely.geometry import Polygon, mapping
import geopandas as gpd
import folium
from folium.plugins import TimeSliderChoropleth
import seaborn as sns
import plotly.express as px

sns.set_style("whitegrid")

import warnings
warnings.filterwarnings("ignore")

# %%
# Load the dataset
wildfires = "C&P_Wildfires.csv"
print("Reading file: '{}'".format(wildfires))
wildfires_df = pd.read_csv(wildfires, parse_dates=[1])
print("Loaded...")
wildfires_df.head()
# Out:
# Reading file: 'C&P_Wildfires.csv'
# Loaded...
#   Region       Date  Estimated_fire_area  Mean_estimated_fire_brightness  \
# 0    NSW 2005-01-04              8.68000                      312.266667
# 1    NSW 2005-01-05             16.61125                      322.475000
# 2    NSW 2005-01-06              5.52000                      325.266667
# 3    NSW 2005-01-07              6.26400                      313.870000
# 4    NSW 2005-01-08              5.40000                      337.383333
#
#    Mean_estimated_fire_radiative_power  Mean_confidence  Std_confidence  \
# 0                            42.400000        78.666667        2.886751
# 1                            62.362500        85.500000        8.088793
# 2                            38.400000        78.333333        3.214550
# 3                            33.800000        92.200000        7.529940
# 4                           122.533333        91.000000        7.937254
#
#    Var_confidence  Count Replaced
# ...

# %%
wildfires_df.columns
# Out:
# Index(['Region', 'Date', 'Estimated_fire_area',
#        'Mean_estimated_fire_brightness', 'Mean_estimated_fire_radiative_power',
#        'Mean_confidence', 'Std_confidence', 'Var_confidence', 'Count',
#        'Replaced'],
#       dtype='object')

# %%
wildfires_df['Date'] = pd.to_datetime(wildfires_df['Date'], errors='coerce')

# %% [markdown]
# #### Estimated Fire Radiative Power Year to Year for All Regions <a class="anchor" id="FireAreaYtY"></a>

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region', data=wildfires_df)

# %% [markdown]
# Note:
# The order of the following regions are for the purposes of looking at the areas sequentially as were reviewed in the previous notebook 3.1 B )  Historical Weather - Trends & Seasonality by Region with Paramaters - Year by Year:
# - 'NSW', 'QL', 'TA', 'WA' ** These areas appears to trend closely in weather parameters; it should be interesting to look at how they trend in historical wilfires over time.
# - 'SA', 'NT', 'VI' ** These areas seemed to be unique in their weather patters with some unique elements happening in each, particular to each region, however, overall they were closely related.

# %% [markdown]
# #### Estimated Fire Radiative Power Year to Year - NSW Region <a class="anchor" id="FireAreaNSW"></a>

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[wildfires_df['Region']=='NSW'])

# %% [markdown]
# #### Estimated Fire Radiative Power Year to Year - QL Region <a class="anchor" id="FireAreaQL"></a>

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[wildfires_df['Region']=='QL'])

# %% [markdown]
# #### Estimated Fire Radiative Power Year to Year - TA Region <a class="anchor" id="FireAreaTA"></a>

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[wildfires_df['Region']=='TA'])

# %% [markdown]
# #### Estimated Fire Radiative Power Year to Year - WA Region <a class="anchor" id="FireAreaWA"></a>

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[wildfires_df['Region']=='WA'])

# %% [markdown]
# #### Estimated Fire Radiative Power Year to Year - 'NSW', 'QL', 'TA', 'WA' Regions <a class="anchor" id="FireArea1stFour"></a>

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[(wildfires_df['Region']=='NSW') | 
                                   (wildfires_df['Region']=='QL') | 
                                   (wildfires_df['Region']=='TA') | 
                                   (wildfires_df['Region']=='WA')])

# %% [markdown]
# Note:
# It will be useful to look at all together in each variation to see which ones are closes to one another in wilfire trend, in comparison to the following weather table trends/seasonality:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# NSW vs. QL

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[(wildfires_df['Region']=='NSW') | 
                                   (wildfires_df['Region']=='QL')])

# %% [markdown]
# NSW vs TA

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[(wildfires_df['Region']=='NSW') | 
                                   (wildfires_df['Region']=='TA')])

# %% [markdown]
# NSW vs. WA

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[(wildfires_df['Region']=='NSW') | 
                                   (wildfires_df['Region']=='WA')])

# %% [markdown]
# Note: NSW and QL appear more closely related to each other (and also in weather trend/seasonality):

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[(wildfires_df['Region']=='NSW') | 
                                   (wildfires_df['Region']=='QL')])

# %% [markdown]
# Note: TA and WA appear more closely related to each other (and also in weather and trend/seasonlity)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[(wildfires_df['Region']=='TA') | 
                                   (wildfires_df['Region']=='WA')])

# %% [markdown]
# #### Estimated Fire Radiative Power Year to Year - SA Region <a class="anchor" id="FireAreaSA"></a>

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[wildfires_df['Region']=='SA'])

# %% [markdown]
# #### Estimated Fire Radiative Power Year to Year - NT Region <a class="anchor" id="FireAreaNT"></a>

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[wildfires_df['Region']=='NT'])

# %% [markdown]
# #### Estimated Fire Radiative Power Year to Year - VI Region <a class="anchor" id="FireAreaVI"></a>

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[wildfires_df['Region']=='VI'])

# %% [markdown]
# #### Estimated Fire Radiative Power Year to Year - 'SA', 'NT', and "VI' Region <a class="anchor" id="FireArea2ndset"></a>

# %% [markdown]
# Note: Doing a comparison of weather and wilfires trends for these three last regions as well

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(16, 6))
sns.set(style="whitegrid")
g = sns.lineplot(x="Date", y="Mean_estimated_fire_radiative_power",hue='Region',
                 data=wildfires_df[(wildfires_df['Region']=='SA') | 
                                   (wildfires_df['Region']=='NT') | 
                                   (wildfires_df['Region']=='VI')])
